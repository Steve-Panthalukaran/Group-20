# %% [markdown]
# # The most dangerous neighborhood

# %% [markdown]
# ## Introduction

# %% [markdown]
# Are there specific times when you feel more concerned about your personal safety? Is your current neighborhood considered safe? Do you worry about staying out at night due to the risk of being robbed or attacked on your way home? Since arriving in this unfamiliar city, these thoughts have been on my mind, especially considering the alerts you receive intermittently. In these circumstances, I'm increasingly eager to identify which neighborhoods are safe and which ones pose potential risks.

# %% [markdown]
# ## The Metric

# %% [markdown]
# Number of Arrests

# %% [markdown]
# ## Metrics Explanation

# %% [markdown]
# In order to find the most dangerous neighborhood, I found a data set called [Pittsburgh Police Arrest Data](https://data.wprdc.org/dataset/arrest-data). In my opinion,this dataset is great for figuring out which neighborhoods might be risky because it records all criminal activities in the area
#
# ![alt text](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExY3FvY2Juamw1YzJrMjJzOHdoeHZvMjRzYjNmdzRnb2o0OXA5bHJrdCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/l2JejeOd6tGGOw3p6/giphy.gif)

# %% [markdown]
# ### Extract the data in this dataset and display the data below

# %%
import pandas as pd

police_arrest = pd.read_csv("Police_Arrest_Data.csv")
_neighborhood = police_arrest['INCIDENTNEIGHBORHOOD']
id_neighborhood = police_arrest[['_id', 'INCIDENTNEIGHBORHOOD']]
print(id_neighborhood)
# Out:
#          _id       INCIDENTNEIGHBORHOOD
# 0          1                 Bloomfield
# 1          2               Outside City
# 2          3                   Westwood
# 3          4             East Allegheny
# 4          5            Crafton Heights
# ...      ...                        ...
# 65170  86431                  Beechview
# 65171  86432  Central Business District
# 65172  86433             East Allegheny
# 65173  86434  Central Business District
# 65174  86435                  Overbrook
#
# [65175 rows x 2 columns]

# %% [markdown]
# #### After having the above data, collect the data and record the number of occurrences of each neighborhood and arrange them from high to low.

# %%
import pandas as pd

# Read the dataset
police_arrest = pd.read_csv("Police_Arrest_Data.csv")

# Count occurrences of each neighborhood and sort in descending order
neighborhood_counts = police_arrest['INCIDENTNEIGHBORHOOD'].value_counts().sort_values(ascending=False)

# Display top 20 neighborhoods by count
top_45_neighborhoods = neighborhood_counts.head(45)
print("Top 45 neighborhoods:")
print(top_45_neighborhoods)
# Out:
# Top 45 neighborhoods:
# Central Business District    4280
# South Side Flats             3399
# Carrick                      2313
# East Allegheny               2162
# Homewood South               2057
# Homewood North               1936
# East Liberty                 1859
# Marshall-Shadeland           1500
# Bluff                        1466
# Mount Washington             1416
# Hazelwood                    1368
# Brookline                    1349
# Lincoln-Lemington-Belmar     1328
# Knoxville                    1306
# Sheraden                     1262
# Allegheny Center             1229
# Beechview                    1172
# East Hills                   1166
# Brighton Heights             1096
# Perry South                  1041
# Bloomfield                    974
# Shadyside                     956
# Allentown                     933
# Middle Hill                   921
# Larimer                       866
# Central North Side            833
# Crawford-Roberts              814
# ...

# %% [markdown]
# ### In order to better reflect the difference between these numbers,I created a bar chart for the top 45 neighborhoods

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
top_45_neighborhoods.plot(kind='bar', color='red')  
plt.title('Top 45 Neighborhoods by Arrest Count')
plt.xlabel('Neighborhood') 
plt.ylabel('Number of Arrests')
plt.xticks(rotation=80)  
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
longitude = police_arrest['X']
latitude = police_arrest['Y']

sns.set(style="darkgrid")

plt.figure(figsize=(20, 12))
sns.scatterplot(x=longitude, y=latitude, s=20, color='blue', alpha=0.8)
plt.title('Dot Map of Number of arrests in Pittsburgh')
plt.xlabel('Longitude')
plt.xlim(-80.10, -79.85)
plt.ylabel('Latitude')
plt.ylim(40.60, 40.30)
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Based on the above data above, the Central Business District has the most arrests, so the Central Business District would be the most dangerous neighborhood in my opinion.But as times progress and society develops, I believe that the crackdown on criminal activities will become increasingly strict in the near future. Consequently, there might come a time where the concepts of danger and safety blur or even cease to exist.
#
# ![alt text](https://media.giphy.com/media/47wO0i3DKzDZyiVkf8/giphy.gif)
